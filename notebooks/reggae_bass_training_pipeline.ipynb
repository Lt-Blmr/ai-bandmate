# %% [markdown]
# # Reggae Bass Training Pipeline
#
# This notebook processes MP3s from a GCS bucket, extracts 2-stem (bass + drums) audio using Demucs,
# converts them into spectral arrays, and prepares the data for model training.
#
# Start from Cell 1 and follow through the pipeline. Make sure you have your GCP bucket and service key ready.
